# %%
#Mount the drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#Importing necessary libraries
import os

# %%
path = '/content/drive/My Drive/ValorantYolo'
os.chdir(path)

# %%
#Clone Darknet Repo
# !git clone https://github.com/AlexeyAB/darknet
# Out:
# fatal: destination path 'darknet' already exists and is not an empty directory.

# %%
# Verify CUDA version
# !/usr/local/cuda/bin/nvcc --version
# Out:
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2020 NVIDIA Corporation
# Built on Mon_Oct_12_20:09:46_PDT_2020
# Cuda compilation tools, release 11.1, V11.1.105
# Build cuda_11.1.TC455_06.29190527_0

# %%
os.chdir("/content/drive/My Drive/ValorantYolo/darknet")
# !make
# Out:
# chmod +x *.sh

# %%
# !./darknet
# Out:
# /bin/bash: ./darknet: Permission denied

# %%
#!wget https://github.com/AlexeyAB/darknet/releases/download/darknet_yolo_v3_optimal/yolov4.weights
# Out:
# --2022-01-05 16:41:14--  https://github.com/AlexeyAB/darknet/releases/download/darknet_yolo_v3_optimal/yolov4-tiny.weights
# Resolving github.com (github.com)... 140.82.112.3
# Connecting to github.com (github.com)|140.82.112.3|:443... connected.
# HTTP request sent, awaiting response... 404 Not Found
# 2022-01-05 16:41:15 ERROR 404: Not Found.

# %%
# !chmod +x ./darknet

# %%
# !./darknet detector test cfg/coco-valorant.data cfg/yolov4-tiny-valorant.cfg yolov4-tiny-valorant.weights data/ValorantImages/clip2\ \(1\).jpg
#!./darknet detector test cfg/coco.data cfg/yolov4.cfg yolov4.weights data/ValorantImages/clip2
#!./darknet detector demo cfg/coco-valorant.data cfg/yolov4-tiny-valorant.cfg yolov4-tiny-valorant.weights -thresh 0.20 -dont_show data/ValorantImages/RangeValorant.mp4 -out_filename data/ValorantImages/ValorantDeathmatch_output_2.mp4
# Out:
#  CUDA-version: 11010 (11020), cuDNN: 7.6.5, GPU count: 1
#  OpenCV version: 3.2.0
#  0 : compute_capability = 370, cudnn_half = 0, GPU: Tesla K80
# net.optimized_memory = 0
# mini_batch = 1, batch = 16, time_steps = 1, train = 0
#    layer   filters  size/strd(dil)      input                output
#    0 Create CUDA-stream - 0
#  Create cudnn-handle 0
# conv     32       3 x 3/ 2    416 x 416 x   3 ->  208 x 208 x  32 0.075 BF
#    1 conv     64       3 x 3/ 2    208 x 208 x  32 ->  104 x 104 x  64 0.399 BF
#    2 conv     64       3 x 3/ 1    104 x 104 x  64 ->  104 x 104 x  64 0.797 BF
#    3 route  2 		                       1/2 ->  104 x 104 x  32
#    4 conv     32       3 x 3/ 1    104 x 104 x  32 ->  104 x 104 x  32 0.199 BF
#    5 conv     32       3 x 3/ 1    104 x 104 x  32 ->  104 x 104 x  32 0.199 BF
#    6 route  5 4 	                           ->  104 x 104 x  64
#    7 conv     64       1 x 1/ 1    104 x 104 x  64 ->  104 x 104 x  64 0.089 BF
# ...

# %%
# Run below lines of code if in case you get Persmission Denied Error
# !sudo chmod +x darknet
# !./darknet

# %%
import cv2
import matplotlib.pyplot as plt
# %matplotlib inline

image = cv2.imread('predictions.jpg')
fig = plt.gcf()
fig.set_size_inches(20, 14)
plt.imshow(image)

# %%
from google.colab import files
files.download('predictions.jpg')
